# %%
ord('👍')
# Out:
# 128077

# %%
chr(128077)
# Out:
# '👍'

# %%
s = chr(0)

# %%
s.__repr__()
# Out:
# "'\\x00'"

# %%
print('\x00')

# %%
chr(0)
# Out:
# '\x00'

# %%
print(chr(0))

# %%
"this is a test" + chr(0) + "string"
# Out:
# 'this is a test\x00string'

# %%
print("this is a test" + chr(0) + "string")
# Out:
# this is a teststring

# %%
test_string = 'hello! 你好呀！👋'
utf8_encoded = test_string.encode("utf-8")

# %%
print(utf8_encoded)
# Out:
# b'hello! \xe4\xbd\xa0\xe5\xa5\xbd\xe5\x91\x80\xef\xbc\x81\xf0\x9f\x91\x8b'

# %%
print(type(utf8_encoded))
# Out:
# <class 'bytes'>

# %%
list(utf8_encoded)
# Out:
# [104,
#  101,
#  108,
#  108,
#  111,
#  33,
#  32,
#  228,
#  189,
#  160,
#  229,
#  165,
#  189,
#  229,
#  145,
#  128,
#  239,
#  188,
#  129,
#  240,
#  159,
#  145,
#  139]

# %%
print(len(test_string))
# Out:
# 12

# %%
print(len(utf8_encoded))
# Out:
# 23

# %%
print(utf8_encoded.decode("utf-8"))
# Out:
# hello! 你好呀！👋

# %%
PAT = r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""

# %%
import regex as re
re.findall(PAT, "some text that i'll pre-tokenize")
# Out:
# ['some', ' text', ' that', ' i', "'ll", ' pre', '-', 'tokenize']

# %%
max([("A", "B"), ("A", "C"), ("B", "ZZ"), ("BA", "A")])
# Out:
# ('BA', 'A')

# %%
bytes([2, 3, 4])
# Out:
# b'\x02\x03\x04'

# %%
bytes(2)
# Out:
# b'\x00\x00'

# %%
"<|endoftext|>".encode('utf-8')
# Out:
# b'<|endoftext|>'

# %%
"👍".encode('utf-8')
# Out:
# b'\xf0\x9f\x91\x8d'
